# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from time import sleep
from selenium.webdriver.support import expected_conditions as EC
import pandas as pd

# %%
options = Options()

options.add_experimental_option("detach", True)
options.add_argument('--no-sanbox')
options.add_argument('--disable-notification')
options.add_argument('--disable-infobars')

# %%
def ScrapTiktokPost(browser,search):
    data = []
    
    #Searching...
    search_input = browser.find_element(By.XPATH,
    "//*[@id='app-header']/div/div[2]/div/form/input")
    search_input.send_keys(search)
    search_input.send_keys(Keys.ENTER)
    sleep(5)

    #menu video...
    ii = 0
    while ii<1:
        try:
            browser.find_element(By.XPATH,'//*[@id="search-tabs"]/div[1]/div[1]/div[1]/div[3]').click()
            ii=1
        except:
            ii=0
            sleep(5)
    
    #Load more...
    i = 0
    while i < 1:
        try:
            lenOfpage = browser.execute_script(
                "window.scrollTo(0, document.body.scrollHeight); var lenOfPage=document.body.scrollHeight; return lenOfPage;")
            match = False
            while (match == False):
                lastCount = lenOfpage
                sleep(8)
                lenOfpage = browser.execute_script(
                    "window.scrollTo(0, document.body.scrollHeight); var lenOfPage=document.body.scrollHeight; return lenOfPage;")
                if lastCount == lenOfpage:
                    match = True
                    raise ValueError(lenOfpage)
            sleep(2)
        except ValueError as ve:
            print(f"Caught an exception: {ve}")
            p = f"{ve}"
            if int(p) > 2000:
                i = 1
    sleep(5)        
    #Scrap Posts...
    
    cards = browser.find_elements(By.CLASS_NAME, "css-1soki6-DivItemContainerForSearch")

    for card in cards:
        #================================Post Description==============================

        desc_part= card.find_element(By.CLASS_NAME,"css-1iy6zew-DivContainer") 
        tags = [tag.text for tag in desc_part.find_elements(By.TAG_NAME,"a")]
        desc = [des.text for des in desc_part.find_elements(By.TAG_NAME,"span")]
        desc = ' '.join(desc)
        tags = ' '.join(tags)
        
        #==================================Post Owner==================================
        
        desc_part = card.find_element(By.CLASS_NAME,"css-1kw4mmh-DivPlayLine")
        username = desc_part.find_element(By.TAG_NAME,"a")
        user_link = username.get_attribute("href")
        user_img = username.find_element(By.TAG_NAME , "img").get_attribute("src")
        name = username.find_element(By.TAG_NAME,"p").text
        vidCount = desc_part.find_element(By.CLASS_NAME , "css-ws4x78-StrongVideoCount").text
        
        #==============================Post Video========================================
        
        desc_part = card.find_element(By.CLASS_NAME,"css-bbkab3-DivContainer")
        post = desc_part.find_element(By.TAG_NAME,"a")
        post_link = post.get_attribute("href")
        post_img = post.find_element(By.TAG_NAME,"img").get_attribute("src")
        #post_vid = postfind_element(By.TAG_NAME,"video").get_attribute("src")
        posted_date = desc_part.find_element(By.CLASS_NAME,"css-dennn6-DivTimeTag").text

        data.append({'Description':desc ,'Tags': tags ,'Username': name ,'User_Img': user_img ,'User_Link': user_link ,'Post_Link': post_link ,'Post_Img': post_img ,'Posted_Date': posted_date ,'Viewer_Count': vidCount})
    browser.close()
    return data

# %%
columns = ['Description', 'Tags', 'Username', 'User_Img', 'User_Link', 'Post_Link', 'Post_Img', 'Posted_Date', 'Viewer_Count']
df = pd.DataFrame(columns=columns)
WordsToSearch  = ['morocco' , 'maroc', 'المغرب']


for search in WordsToSearch:
    
    #THIS INITIALIZES THE DRIVER (AKA THE WEB BROWSER)
    browser = webdriver.Chrome(options=options)
    
    #load the webpage
    browser.get('https://www.tiktok.com')
    
    #Get the Data 
    db = ScrapTiktokPost(browser,search)
    
    df = df.append(db, ignore_index=True)
    print(len(db))
# Out:
# Caught an exception: 1314
# Caught an exception: 1314
# Caught an exception: 60349
# C:\Users\dell\AppData\Local\Temp\ipykernel_4716\3866993291.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(db, ignore_index=True)
# 204
# Caught an exception: 1314
# Caught an exception: 1314
# Caught an exception: 1314
# Caught an exception: 1314
# Caught an exception: 1314
# Caught an exception: 6678
# C:\Users\dell\AppData\Local\Temp\ipykernel_4716\3866993291.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(db, ignore_index=True)
# 21
# Caught an exception: 1314
# Caught an exception: 1314
# Caught an exception: 1314
# Caught an exception: 1314
# Caught an exception: 3730
# 12
# C:\Users\dell\AppData\Local\Temp\ipykernel_4716\3866993291.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(db, ignore_index=True)

# %%
# Display the original DataFrame
print("Original DataFrame:")
df
# Out:
# Original DataFrame:
#                                            Description  \
# 0    Honestly I didn’t know Morocco was this beauti...
# 1                             morocco🇲🇦🤤
# 2    📍Ifrane, the 'Switzerland of Morocco,' where t...
# 3    🏆 Les compétitions qui seront organisées au Ma...
# 4
# ..                                                 ...
# 232
# 233  THE MOROCCAN MIRACLE. One of the greatest Worl...
# 234
# 235
# 236
#
#                                                   Tags           Username  \
# 0                               #morocco #edit #phonk           wernervfx
# 1    #foryoupage #fyb #explor #fypage #morocco #vir...          moro__cco
# 2                                                         exploremorocco6
# 3                                                              ___morocco
# 4    @ihsanelkettani #madeinmorocco #madeinmorocco🇲...  kingdom_ofmorocco
# ..                                                 ...                ...
# 232  #المغرب🇲🇦تونس🇹🇳الجزائر🇩🇿 #maria_nadim #foryoup...        btissamelh3
# 233                                                          fifaworldcup
# 234                      #fyp #foryou #المغرب #morocco        fbioussamaa
# 235  #المملكة_المغربية_الشريفة🇲🇦 #المغرب🇲🇦 #اكادير_...         rachid.340
# 236  #الشعب_الصيني_ماله_حل😂😂 #تصميمي #ستوريات #expl...    na.dia.officiel
#
#                                               User_Img  \
# 0    https://p16-sign-useast2a.tiktokcdn.com/tos-us...
# 1    https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 2    https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 3    https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 4    https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# ..                                                 ...
# 232  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 233  https://p16-sign-useast2a.tiktokcdn.com/tos-us...
# 234  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 235  https://p77-sign-va.tiktokcdn.com/tos-maliva-a...
# 236  https://p77-sign-va.tiktokcdn.com/tos-maliva-a...
#
#                                      User_Link  \
# 0            https://www.tiktok.com/@wernervfx
# 1            https://www.tiktok.com/@moro__cco
# 2      https://www.tiktok.com/@exploremorocco6
# 3           https://www.tiktok.com/@___morocco
# 4    https://www.tiktok.com/@kingdom_ofmorocco
# ..                                         ...
# 232        https://www.tiktok.com/@btissamelh3
# 233       https://www.tiktok.com/@fifaworldcup
# 234        https://www.tiktok.com/@fbioussamaa
# 235         https://www.tiktok.com/@rachid.340
# 236    https://www.tiktok.com/@na.dia.officiel
#
#                                              Post_Link  \
# 0    https://www.tiktok.com/@wernervfx/video/725296...
# 1    https://www.tiktok.com/@moro__cco/video/710993...
# 2    https://www.tiktok.com/@exploremorocco6/video/...
# 3    https://www.tiktok.com/@___morocco/video/72862...
# 4    https://www.tiktok.com/@kingdom_ofmorocco/vide...
# ..                                                 ...
# 232  https://www.tiktok.com/@btissamelh3/video/7297...
# 233  https://www.tiktok.com/@fifaworldcup/video/718...
# 234  https://www.tiktok.com/@fbioussamaa/video/7306...
# 235  https://www.tiktok.com/@rachid.340/video/73051...
# 236  https://www.tiktok.com/@na.dia.officiel/video/...
#
#                                               Post_Img Posted_Date  \
# 0    https://p16-sign-useast2a.tiktokcdn.com/tos-us...         7-7
# 1    https://p16-sign-va.tiktokcdn.com/obj/tos-mali...   2022-6-16
# 2    https://p16-sign-va.tiktokcdn.com/obj/tos-mali...       11-24
# 3    https://p16-sign-va.tiktokcdn.com/obj/tos-mali...        10-4
# 4    https://p16-sign-va.tiktokcdn.com/obj/tos-mali...       10-16
# ..                                                 ...         ...
# 232  ......        11-3
# 233  ......         1-6
# 234  ......       11-28
# 235  ......       11-24
# 236  ......       11-18
#
#     Viewer_Count
# 0           2.4M
# 1         919.3K
# 2         916.3K
# 3             1M
# 4         659.3K
# ..           ...
# 232         3.7M
# 233         3.8M
# 234         509K
# 235       917.2K
# 236         1.2M
#
# [237 rows x 9 columns]

# %%
from datetime import datetime, timedelta


def convert_to_date(date_str):
    try:
        # If the string is in 'YYYY-MM-DD' format, return it as is
        return pd.to_datetime(date_str).strftime('%Y-%m-%d')
    except ValueError:
        pass

    try:
        # If the string is in 'MM-DD' format, append the current year
        current_year = datetime.now().year
        return pd.to_datetime(f"{current_year}-{date_str}", format='%Y-%m-%d').strftime('%Y-%m-%d')
    except ValueError:
        pass

    try:
        # If the string is in 'Xh ago' format, subtract hours from the current date
        hours_ago = int(date_str.split('h')[0])
        current_date = datetime.now() - timedelta(hours=hours_ago)
        return current_date.strftime('%Y-%m-%d')
    except ValueError:
        pass

    # If all conversion attempts fail, return NaN
    return pd.NaT



# Function to convert Count Viewer from String To Numbre
def StringToNumber(strr):
    if 'K' in strr:
        hours_ago = float(strr.split('K')[0]) * 1000
    elif 'M' in strr:
        hours_ago = float(strr.split('M')[0]) * 1000000
    else:
        hours_ago = float(strr)
    return hours_ago


# Apply the functions to the columns
new_df = df
new_df['Posted_Date'] = new_df['Posted_Date'].apply(convert_to_date)
new_df['Viewer_Count'] = new_df['Viewer_Count'].apply(StringToNumber)

# %%
# Display the DataFrame after conversion
print("\nDataFrame after conversion:")
new_df[20:25]
# Out:
# DataFrame after conversion:
#                                           Description  \
# 20  اشنو كتقولو في هاذ ظاهرة لايف تيك توك لي ولات ...
# 21  مكان خرافي في مراكش 😱 اكتاشفناه صدفة و ها اشنو...
# 22                                        ❤️
# 23  Girls riding stallions at the beach of Essaoui...
# 24                    Things to do in Morocco! 🇲🇦🤩
#
#                                                  Tags                Username  \
# 20   #wahibabouya #fyp #morocco #trending                         wahibabouya
# 21                                                           reda_food_review
# 22  #fypシ #fyp #morocco #chefchaouen #capcut #capc...           mohameddaoud1
# 23                                                     essaouirahorseparadise
# 24                    #Morocco #travel #travelmorocco          visit.morocco_
#
#                                              User_Img  \
# 20  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 21  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 22  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 23  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 24  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
#
#                                          User_Link  \
# 20             https://www.tiktok.com/@wahibabouya
# 21        https://www.tiktok.com/@reda_food_review
# 22           https://www.tiktok.com/@mohameddaoud1
# 23  https://www.tiktok.com/@essaouirahorseparadise
# 24          https://www.tiktok.com/@visit.morocco_
#
#                                             Post_Link  \
# 20  https://www.tiktok.com/@wahibabouya/video/7312...
# 21  https://www.tiktok.com/@reda_food_review/video...
# 22  https://www.tiktok.com/@mohameddaoud1/video/72...
# 23  https://www.tiktok.com/@essaouirahorseparadise...
# 24  https://www.tiktok.com/@visit.morocco_/video/7...
#
#                                              Post_Img Posted_Date  \
# 20  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...         NaT
# 21  https://p16-sign-va.tiktokcdn.com/tos-maliva-p...  2023-12-15
# 22  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  2023-10-21
# 23  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  2023-12-15
# 24  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  2023-12-02
#
#     Viewer_Count
# 20     1600000.0
# 21       25600.0
# 22     1300000.0
# 23        8427.0
# 24      724100.0

# %% [markdown]
# new_df.to_csv(r'C:\Users\dell\Desktop\Job\TikTokPost-2.csv',index=False)
